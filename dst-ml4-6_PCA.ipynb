# %%
# загрузим датасет MNIST
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

dataset = fetch_openml("mnist_784")
# загрузим признаки в переменную X  
X = dataset['data']
# загрузим «ответы» в переменную y
y = dataset['target']
# разделим данные с помощью sklearn на данные для обучения и теста
train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.1, random_state=0)

# импортируем StandardScaler для стандартизации данных
from sklearn.preprocessing import StandardScaler

# создадим объект класса StandardScaler
scaler = StandardScaler()
scaler.fit(train_x)
# трансформируем датасеты train_x и test_x
train_x = scaler.transform(train_x)
test_x = scaler.transform(test_x)

# импортируем класс PCA
from sklearn.decomposition import PCA

# создадим объект класса PCA
pca = PCA(n_components=300)
pca.fit(train_x)
# уменьшим размерность данных
train_x_pca = pca.transform(train_x)
test_x_pca = pca.transform(test_x)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from time import time

# напишем функцию, которая на вход принимает X и y, а возвращает модель и время
def get_time_and_accuracy(train_x, train_y, test_x, test_y):
    # создадим объект класса LogisticRegression
    log_reg_model = LogisticRegression(max_iter=1000)
    # запишем время с начала эпохи в секундах до обучения модели
    start_time = time()
    # обучим модель
    log_reg_model.fit(train_x, train_y)    
    # запишем время с начала эпохи в секундах после обучения
    end_time = time()
    # подсчитаем время, потраченное на обучение модели
    delta_time = end_time-start_time
    # предскажем на тестовых данных
    y_pred = log_reg_model.predict(test_x)
    # посчитаем скор для тестового предсказания
    score = accuracy_score(test_y, y_pred)
    # вернём время, потраченное на обучение, и качество полученной модели
    return delta_time, score

model_pca_time, model_pca_acc = get_time_and_accuracy(train_x_pca, train_y, test_x_pca, test_y)
print(f"Модель, построенная на признаках, полученных после уменьшения размерности. Время обучения {model_pca_time}, метрика модели {model_pca_acc}")
# Модель, построенная на признаках, полученных после уменьшения размерности. Время обучения 54.12072825431824, метрика модели 0.9255714285714286

model_time, model_acc = get_time_and_accuracy(train_x, train_y, test_x, test_y)
print(f"Модель, построенная на всех исходных признаках. Время обучения {model_time}, метрика модели {model_acc}")
# Модель, построенная на всех исходных признаках. Время обучения 108.04033303260803, метрика модели 0.9187142857142857
# Out:
# Модель, построенная на признаках, полученных после уменьшения размерности. Время обучения 11.797592878341675, метрика модели 0.926
# Модель, построенная на всех исходных признаках. Время обучения 16.796114921569824, метрика модели 0.919

# %%
# импортируем класс TSNE из модуля manifold библиотеки sklearn
from sklearn.manifold import TSNE

# создаём объект класса TSNE
# n_components — размерность нового пространства
tsne = TSNE(n_components=2, perplexity=30, max_iter=500, random_state=42)
# обучаем модель на данных X и производим трансформацию
tsne.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       6 tsne = TSNE(n_components=2, perplexity=30, max_iter=500, random_state=42)
#       7 # обучаем модель на данных X и производим трансформацию
# ----> 8 tsne.fit_transform(X)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1176, in TSNE.fit_transform(self, X, y)
#    1173     self._max_iter = self.max_iter
#    1175 self._check_params_vs_input(X)
# -> 1176 embedding = self._fit(X)
#    1177 self.embedding_ = embedding
#    1178 return self.embedding_
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:995, in TSNE._fit(self, X, skip_num_points)
#     988     print(
#     989         "[t-SNE] Indexed {} samples in {:.3f}s...".format(
#     990             n_samples, duration
#     991         )
#     992     )
#     994 t0 = time()
# --> 995 distances_nn = knn.kneighbors_graph(mode="distance")
#     996 duration = time() - t0
#     997 if self.verbose:
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/neighbors/_base.py:1012, in KNeighborsMixin.kneighbors_graph(self, X, n_neighbors, mode)
#    1009     A_data = np.ones(n_queries * n_neighbors)
#    1011 elif mode == "distance":
# -> 1012     A_data, A_ind = self.kneighbors(X, n_neighbors, return_distance=True)
#    1013     A_data = np.ravel(A_data)
#    1015 else:
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/neighbors/_base.py:849, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     842 use_pairwise_distances_reductions = (
#     843     self._fit_method == "brute"
#     844     and ArgKmin.is_usable_for(
#     845         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     846     )
#     847 )
#     848 if use_pairwise_distances_reductions:
# --> 849     results = ArgKmin.compute(
#     850         X=X,
#     851         Y=self._fit_X,
#     852         k=n_neighbors,
#     853         metric=self.effective_metric_,
#     854         metric_kwargs=self.effective_metric_params_,
#     855         strategy="auto",
#     856         return_distance=return_distance,
#     857     )
#     859 elif (
#     860     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     861 ):
#     862     results = _kneighbors_from_graph(
#     863         X, n_neighbors=n_neighbors, return_distance=return_distance
#     864     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_pairwise_distances_reduction/_dispatcher.py:290, in ArgKmin.compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     278     return ArgKmin64.compute(
#     279         X=X,
#     280         Y=Y,
#    (...)
#     286         return_distance=return_distance,
#     287     )
#     289 if X.dtype == Y.dtype == np.float32:
# --> 290     return ArgKmin32.compute(
#     291         X=X,
#     292         Y=Y,
#     293         k=k,
#     294         metric=metric,
#     295         chunk_size=chunk_size,
#     296         metric_kwargs=metric_kwargs,
#     297         strategy=strategy,
#     298         return_distance=return_distance,
#     299     )
#     301 raise ValueError(
#     302     "Only float64 or float32 datasets pairs are supported at this time, "
#     303     f"got: X.dtype={X.dtype} and Y.dtype={Y.dtype}."
#     304 )
#
# File sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx:550, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin32.compute()
#
# File /opt/anaconda3/lib/python3.12/site-packages/threadpoolctl.py:592, in _ThreadpoolLimiter.__exit__(self, type, value, traceback)
#     589 def __enter__(self):
#     590     return self
# --> 592 def __exit__(self, type, value, traceback):
#     593     self.restore_original_limits()
#     595 @classmethod
#     596 def wrap(cls, controller, *, limits=None, user_api=None):
#
# KeyboardInterrupt:

# %%
import seaborn as sns
import pandas as pd

# создадим объект класса PCA, уменьшим размерность данных до 2
pca = PCA(n_components=2, random_state=42)
# уменьшим размерность данных
X_reduced = pca.fit_transform(train_x)
# сохраним данные в датафрейм
df_pca = pd.DataFrame(X_reduced)
# сохраним разметки кластеров
df_pca['c'] = pd.to_numeric(train_y).astype('Int64').to_list()
# визуализируем
sns.scatterplot(x=df_pca[0], y=df_pca[1], c=df_pca['c'])
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
# импортируем класс TSNE из модуля manifold библиотеки sklearn
from sklearn.manifold import TSNE
# создадим объект класса TSNE, уменьшим размерность данных до 2
tsne = TSNE(n_components=2, perplexity=50, max_iter=250, random_state=42)
# уменьшим размерность данных
X_reduced = tsne.fit_transform(train_x)
# сохраним данные в датафрейм
df_tsne = pd.DataFrame(X_reduced)
# сохраним разметки кластеров
df_tsne['c'] = pd.to_numeric(train_y).astype('Int64').to_list()# визуализируем
sns.scatterplot(x=df_tsne[0], y=df_tsne[1], c=df_tsne['c'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 6
#       4 tsne = TSNE(n_components=2, perplexity=50, max_iter=250, random_state=42)
#       5 # уменьшим размерность данных
# ----> 6 X_reduced = tsne.fit_transform(train_x)
#       7 # сохраним данные в датафрейм
#       8 df_tsne = pd.DataFrame(X_reduced)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1176, in TSNE.fit_transform(self, X, y)
#    1173     self._max_iter = self.max_iter
#    1175 self._check_params_vs_input(X)
# -> 1176 embedding = self._fit(X)
#    1177 self.embedding_ = embedding
#    1178 return self.embedding_
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1044, in TSNE._fit(self, X, skip_num_points)
#    1038 # Degrees of freedom of the Student's t-distribution. The suggestion
#    1039 # degrees_of_freedom = n_components - 1 comes from
#    1040 # "Learning a Parametric Embedding by Preserving Local Structure"
#    1041 # Laurens van der Maaten, 2009.
#    1042 degrees_of_freedom = max(self.n_components - 1, 1)
# -> 1044 return self._tsne(
#    1045     P,
#    1046     degrees_of_freedom,
#    1047     n_samples,
#    1048     X_embedded=X_embedded,
#    1049     neighbors=neighbors_nn,
#    1050     skip_num_points=skip_num_points,
#    1051 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1096, in TSNE._tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#    1093 # Learning schedule (part 1): do 250 iteration with lower momentum but
#    1094 # higher learning rate controlled via the early exaggeration parameter
#    1095 P *= self.early_exaggeration
# -> 1096 params, kl_divergence, it = _gradient_descent(obj_func, params, **opt_args)
#    1097 if self.verbose:
#    1098     print(
#    1099         "[t-SNE] KL divergence after %d iterations with early exaggeration: %f"
#    1100         % (it + 1, kl_divergence)
#    1101     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:403, in _gradient_descent(objective, p0, it, max_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     400 # only compute the error when needed
#     401 kwargs["compute_error"] = check_convergence or i == max_iter - 1
# --> 403 error, grad = objective(p, *args, **kwargs)
#     405 inc = update * grad < 0.0
#     406 dec = np.invert(inc)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:284, in _kl_divergence_bh(params, P, degrees_of_freedom, n_samples, n_components, angle, skip_num_points, verbose, compute_error, num_threads)
#     281 indptr = P.indptr.astype(np.int64, copy=False)
#     283 grad = np.zeros(X_embedded.shape, dtype=np.float32)
# --> 284 error = _barnes_hut_tsne.gradient(
#     285     val_P,
#     286     X_embedded,
#     287     neighbors,
#     288     indptr,
#     289     grad,
#     290     angle,
#     291     n_components,
#     292     verbose,
#     293     dof=degrees_of_freedom,
#     294     compute_error=compute_error,
#     295     num_threads=num_threads,
#     296 )
#     297 c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
#     298 grad = grad.ravel()
#
# KeyboardInterrupt:
